# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

train_df = pd.read_csv("BostonHouseTrain.csv", index_col=0)
test_df = pd.read_csv("BostonHouseTest.csv", index_col=0)

# %% [markdown]
# ### Question 1

# %%
from sklearn.tree import DecisionTreeClassifier

X_train = train_df.drop("class", axis=1)
y_train = pd.DataFrame(data=train_df["class"], columns=["class"])

X_test = test_df.drop("class", axis=1)
y_test = pd.DataFrame(data=test_df["class"], columns=["class"])

tree = DecisionTreeClassifier(random_state=0)
tree.fit(X_train, y_train)

y_train_pred = tree.predict(X_train)
y_test_pred = tree.predict(X_test)

# %% [markdown]
# ### Question 2

# %%
from sklearn.metrics import accuracy_score

score_train = accuracy_score(y_train, y_train_pred)
score_test = accuracy_score(y_test, y_test_pred)
print(score_train)
print(score_test)
# Out:
# 1.0
# 0.7641509433962265

# %%
tree.tree_.node_count   # For node number, not sure
# Out:
# 145

# %% [markdown]
# ### Question 3

# %%
Run = []
NodeCount = []
TrainAcc = []
TestAcc = []
frame = pd.DataFrame(columns = ["Run", "NodeCount", "TrainAcc", "TestAcc"])

for i in range(100):
    small_subset = train_df.sample(frac=0.25, replace=True, random_state=i)

    X_train2 = small_subset.drop("class", axis=1)
    y_train2 = pd.DataFrame(data=small_subset["class"], columns=["class"])
    X_test2 = test_df.drop("class", axis=1)
    y_test2 = pd.DataFrame(data=test_df["class"], columns=["class"])

    tree2 = DecisionTreeClassifier(random_state=0)
    tree2.fit(X_train2, y_train2)

    y_train_pred2 = tree2.predict(X_train2)
    y_test_pred2 = tree2.predict(X_test2)
    
    Run.append(i)
    NodeCount.append(tree2.tree_.node_count)
    TrainAcc.append(accuracy_score(y_train2, y_train_pred2))
    TestAcc.append(accuracy_score(y_test2, y_test_pred2))
    
    #frame.iloc[i, 0] = i
    #frame.iloc[i, 1] = tree2.tree_.node_count
    #frame.iloc[i, 2] = accuracy_score(y_train2, y_train_pred2)
    #frame.iloc[i, 3] = accuracy_score(y_test2, y_test_pred2)
    
mean_nb_nodes = np.mean(NodeCount)
mean_train_accur = np.mean(TrainAcc)
mean_test_accur = np.mean(TestAcc)

frame["Run"] = Run
frame["NodeCount"] = NodeCount
frame["TrainAcc"] = TrainAcc
frame["TestAcc"] = TestAcc
frame
# Out:
#     Run  NodeCount  TrainAcc   TestAcc
# 0     0         29       1.0  0.735849
# 1     1         31       1.0  0.764151
# 2     2         35       1.0  0.679245
# 3     3         39       1.0  0.707547
# 4     4         33       1.0  0.716981
# ..  ...        ...       ...       ...
# 95   95         45       1.0  0.716981
# 96   96         41       1.0  0.726415
# 97   97         41       1.0  0.707547
# 98   98         35       1.0  0.679245
# 99   99         37       1.0  0.603774
#
# [100 rows x 4 columns]

# %%
# Out:
# 0.7641509433962267

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

frame = pd.DataFrame(columns = ["Frac", "Run", "NodeCount", "TrainAcc", "TestAcc"])

Frac = []
Run = []
NodeCount = []
TrainAcc = []
TestAcc = []

for i in range(100):
    small_subset = train_df.sample(frac=0.05, random_state=i)
    Frac.append(0.05)

    X_train2 = small_subset.drop("class", axis=1)
    y_train2 = pd.DataFrame(data=small_subset["class"], columns=["class"])
    X_test2 = test_df.drop("class", axis=1)
    y_test2 = pd.DataFrame(data=test_df["class"], columns=["class"])

    tree2 = DecisionTreeClassifier(random_state=0)
    tree2.fit(X_train2, y_train2)

    y_train_pred2 = tree2.predict(X_train2)
    y_test_pred2 = tree2.predict(X_test2)
    
    Run.append(i)
    NodeCount.append(tree2.tree_.node_count)
    TrainAcc.append(accuracy_score(y_train2, y_train_pred2))
    TestAcc.append(accuracy_score(y_test2, y_test_pred2))
for i in range(100):
    small_subset = train_df.sample(frac=0.1, random_state=i)
    Frac.append(0.1)

    X_train2 = small_subset.drop("class", axis=1)
    y_train2 = pd.DataFrame(data=small_subset["class"], columns=["class"])
    X_test2 = test_df.drop("class", axis=1)
    y_test2 = pd.DataFrame(data=test_df["class"], columns=["class"])

    tree2 = DecisionTreeClassifier(random_state=0)
    tree2.fit(X_train2, y_train2)

    y_train_pred2 = tree2.predict(X_train2)
    y_test_pred2 = tree2.predict(X_test2)
    
    Run.append(i)
    NodeCount.append(tree2.tree_.node_count)
    TrainAcc.append(accuracy_score(y_train2, y_train_pred2))
    TestAcc.append(accuracy_score(y_test2, y_test_pred2))
for i in range(100):
    small_subset = train_df.sample(frac=0.2, random_state=i)
    Frac.append(0.2)

    X_train2 = small_subset.drop("class", axis=1)
    y_train2 = pd.DataFrame(data=small_subset["class"], columns=["class"])
    X_test2 = test_df.drop("class", axis=1)
    y_test2 = pd.DataFrame(data=test_df["class"], columns=["class"])

    tree2 = DecisionTreeClassifier(random_state=0)
    tree2.fit(X_train2, y_train2)

    y_train_pred2 = tree2.predict(X_train2)
    y_test_pred2 = tree2.predict(X_test2)
    
    Run.append(i)
    NodeCount.append(tree2.tree_.node_count)
    TrainAcc.append(accuracy_score(y_train2, y_train_pred2))
    TestAcc.append(accuracy_score(y_test2, y_test_pred2))
for i in range(100):
    small_subset = train_df.sample(frac=0.5, random_state=i)
    Frac.append(0.5)

    X_train2 = small_subset.drop("class", axis=1)
    y_train2 = pd.DataFrame(data=small_subset["class"], columns=["class"])
    X_test2 = test_df.drop("class", axis=1)
    y_test2 = pd.DataFrame(data=test_df["class"], columns=["class"])

    tree2 = DecisionTreeClassifier(random_state=0)
    tree2.fit(X_train2, y_train2)

    y_train_pred2 = tree2.predict(X_train2)
    y_test_pred2 = tree2.predict(X_test2)
    
    Run.append(i)
    NodeCount.append(tree2.tree_.node_count)
    TrainAcc.append(accuracy_score(y_train2, y_train_pred2))
    TestAcc.append(accuracy_score(y_test2, y_test_pred2))
for i in range(100):
    small_subset = train_df.sample(frac=0.99, random_state=i)
    Frac.append(0.99)

    X_train2 = small_subset.drop("class", axis=1)
    y_train2 = pd.DataFrame(data=small_subset["class"], columns=["class"])
    X_test2 = test_df.drop("class", axis=1)
    y_test2 = pd.DataFrame(data=test_df["class"], columns=["class"])

    tree2 = DecisionTreeClassifier(random_state=0)
    tree2.fit(X_train2, y_train2)

    y_train_pred2 = tree2.predict(X_train2)
    y_test_pred2 = tree2.predict(X_test2)
    
    Run.append(i)
    NodeCount.append(tree2.tree_.node_count)
    TrainAcc.append(accuracy_score(y_train2, y_train_pred2))
    TestAcc.append(accuracy_score(y_test2, y_test_pred2))


frame["Frac"] = Frac
frame["Run"] = Run
frame["NodeCount"] = NodeCount
frame["TrainAcc"] = TrainAcc
frame["TestAcc"] = TestAcc

# %%
frame.boxplot(["TestAcc"], by=["Frac"])
# Out:
# <AxesSubplot:title={'center':'TestAcc'}, xlabel='[Frac]'>

# %%
frame.boxplot(["NodeCount"], by=["Frac"])
# Out:
# <AxesSubplot:title={'center':'NodeCount'}, xlabel='[Frac]'>

# %% [markdown]
# ## A1.4 - Decision Tree Learning

# %%
wl = DecisionTreeClassifier(random_state=0, max_depth=2)
wl.fit(X_train, y_train)
wl_pred = wl.predict(X_test)
wl_accuracy = accuracy_score(y_test, wl_pred)

# %%
wl_accuracy
# Out:
# 0.7830188679245284

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier

accur = []

for i in range(10):
    bagging = BaggingClassifier(
        DecisionTreeClassifier(random_state=0, max_depth=2), n_estimators=1,
        max_samples=100, bootstrap=True, n_jobs=-1)
    bagging.fit(X_train, y_train)
    bag_pred = bagging.predict(X_test)
    bag_accuracy = accuracy_score(y_test, bag_pred)
    accur.append(bag_accuracy)
    
mean_test_accur = np.mean(accur)
# Out:
# C:\Users\nilsb\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\nilsb\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\nilsb\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
mean_test_accur
# Out:
# 0.8235849056603775

# %%
mean_acc = []
for i in range(1, 100):
    accur = []
    bagging = BaggingClassifier(
        DecisionTreeClassifier(random_state=0, max_depth=2), n_estimators=i,
        max_samples=100, bootstrap=True, n_jobs=-1)
    for j in range(10):
        bagging.fit(X_train, y_train)
        bag_pred = bagging.predict(X_test)
        bag_accuracy = accuracy_score(y_test, bag_pred)
        accur.append(bag_accuracy)

    mean_test_accur = np.mean(accur)
    mean_acc.append(mean_test_accur)

plt.plot(mean_acc)
# Out:
# C:\Users\nilsb\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\nilsb\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\nilsb\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

all_accur = []
means_accur = []
for i in range(1,50):
    accur = []
    for j in range(2,10):
        mean_test = []
        for k in range(20):
            RFC = RandomForestClassifier(n_estimators=i, max_leaf_nodes=2**j, n_jobs=-1)
            RFC.fit(X_train, y_train)
            RFC_pred = RFC.predict(X_test)
            score = accuracy_score(y_test, RFC_pred)
            mean_test.append(score)
        accur.append(np.mean(mean_test))
    all_accur.append(accur)
    means_accur.append(np.mean(accur))
# Out:
# <ipython-input-4-a669eeccf9cb>:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC.fit(X_train, y_train)
# <ipython-input-4-a669eeccf9cb>:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC.fit(X_train, y_train)
# <ipython-input-4-a669eeccf9cb>:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC.fit(X_train, y_train)
# <ipython-input-4-a669eeccf9cb>:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC.fit(X_train, y_train)
# ...

# %%
plt.plot(means_accur)

# %%
plt.plot(all_accur)

# %%
#np.argmax(means_accur)
acc = np.array(all_accur)
t1 = pd.DataFrame(acc, columns =["n_estimators", "1", "2", "3", "4", "5", "6", "7"])
# Out:
#     n_estimators         1         2         3         4         5         6  \
# 0       0.705660  0.717925  0.745755  0.758491  0.758019  0.738208  0.730189
# 1       0.752830  0.756132  0.772170  0.772642  0.740566  0.740566  0.758019
# 2       0.751887  0.797170  0.797170  0.800943  0.790566  0.790094  0.796226
# 3       0.784906  0.798113  0.808019  0.793396  0.784434  0.783491  0.783019
# 4       0.791038  0.814623  0.817925  0.816038  0.801887  0.806604  0.805189
# 5       0.786321  0.816038  0.831604  0.822170  0.813679  0.803774  0.802830
# 6       0.793868  0.822170  0.828302  0.822642  0.812736  0.820283  0.801887
# 7       0.795755  0.822170  0.818396  0.833491  0.810849  0.821226  0.820755
# 8       0.795283  0.825000  0.828774  0.833019  0.825472  0.813679  0.816509
# 9       0.792925  0.820755  0.833019  0.831604  0.835849  0.817925  0.816981
# 10      0.800000  0.824528  0.831132  0.836321  0.822170  0.819811  0.820283
# ...

# %%
vec = []
for i in range(acc.shape[0]):
    max_pos = np.argmax(acc[i])
    max_value = np.amax(acc[i])
    duo = np.array([max_pos, max_value])
    vec.append(duo)

# %%
t = pd.DataFrame(vec, columns =["Pos", "Val"]) 
t
# Out:
#     Pos       Val
# 0   3.0  0.758491
# 1   3.0  0.772642
# 2   3.0  0.800943
# 3   2.0  0.808019
# 4   7.0  0.821698
# 5   2.0  0.831604
# 6   2.0  0.828302
# 7   3.0  0.833491
# 8   3.0  0.833019
# 9   4.0  0.835849
# 10  3.0  0.836321
# 11  2.0  0.835849
# 12  3.0  0.835377
# 13  2.0  0.843396
# 14  3.0  0.839623
# 15  3.0  0.837736
# 16  3.0  0.841038
# 17  2.0  0.842925
# 18  2.0  0.840566
# 19  3.0  0.843396
# 20  2.0  0.844340
# 21  2.0  0.840566
# 22  2.0  0.843396
# 23  2.0  0.839151
# 24  2.0  0.847170
# 25  2.0  0.844340
# 26  2.0  0.847170
# 27  3.0  0.845283
# 28  3.0  0.843868
# 29  1.0  0.842453
# 30  2.0  0.845755
# 31  3.0  0.844340
# 32  2.0  0.844811
# 33  3.0  0.847170
# 34  2.0  0.849057
# 35  2.0  0.844340
# 36  3.0  0.846698
# 37  2.0  0.847170
# 38  3.0  0.852830
# 39  3.0  0.852358
# 40  2.0  0.847170
# 41  2.0  0.844811
# 42  3.0  0.841509
# 43  2.0  0.846226
# 44  2.0  0.843868
# 45  2.0  0.850943
# 46  2.0  0.847642
# 47  3.0  0.845755
# 48  2.0  0.845283

# %%
all_val = np.array(t["Val"])
np.argmax(all_val)
# Out:
# 38

# %%
RFC2 = RandomForestClassifier(n_estimators=38, max_leaf_nodes=16, n_jobs=-1)
RFC2.fit(X_train, y_train)
RFC2_pred = RFC2.predict(X_test)
accuracy_score(y_test, RFC2_pred)
# Out:
# <ipython-input-252-c0aa3321a30e>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RFC2.fit(X_train, y_train)
# 0.8679245283018868

# %% [markdown]
# # Final Solution

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import time
start_time = time.time()

X_train = train_df.drop("class", axis=1)
y_train = pd.DataFrame(data=train_df["class"], columns=["class"])

X_test = test_df.drop("class", axis=1)
y_test = pd.DataFrame(data=test_df["class"], columns=["class"])

all_accur = []
means_accur = []
for i in range(15,42):
    accur = []
    for j in range(2,5):
        mean_test = []
        for k in range(3):
            RFC = RandomForestClassifier(n_estimators=i, max_leaf_nodes=2**j) #, n_jobs=-1)
            RFC.fit(X_train, y_train)
            RFC_pred = RFC.predict(X_test)
            score = accuracy_score(y_test, RFC_pred)
            mean_test.append(score)
        accur.append(np.mean(mean_test))
    all_accur.append(accur)
    means_accur.append(np.mean(accur))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 6.255083322525024 seconds ---

# %%
# Function found on internet : https://thispointer.com/python-find-indexes-of-an-element-in-pandas-dataframe/
def getIndexes(dfObj, value):
    ''' Get index positions of value in dataframe i.e. dfObj.'''
    listOfPos = list()
    # Get bool dataframe with True at positions where the given value exists
    result = dfObj.isin([value])
    # Get list of columns that contains the value
    seriesObj = result.any()
    columnNames = list(seriesObj[seriesObj == True].index)
    # Iterate over list of columns and fetch the rows indexes where value exists
    for col in columnNames:
        rows = list(result[col][result[col] == True].index)
        for row in rows:
            listOfPos.append((row, col))
    # Return a list of tuples indicating the positions of value in the dataframe
    return listOfPos

acc = np.array(all_accur)
t1 = pd.DataFrame(acc, columns =["n_estimators", "1", "2"]) #, "5", "6", "7"]) 

max_accur = t1.max().max() # Finding the highest accuracy in the dataframe
indexes = getIndexes(t1, max_accur) # Finding the position of the highest accuracy
index = indexes[0] 

N_estimators = index[0]+15  # Best number of estimators 
Max_leaf_nodes = 2**(int(index[1])+2) # Best number of maximum leaf nodes

my_best_forest = RandomForestClassifier(n_estimators=N_estimators, max_leaf_nodes=Max_leaf_nodes, n_jobs=-1)

# %%
my_best_forest.fit(X_train, y_train)
RFC_pred = RFC.predict(X_test)
accuracy_score(y_test, RFC_pred)
# Out:
# 0.8584905660377359

# %%
index
# Out:
# (13, '2')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
start_time = time.time()

# Preparation of the differents data sets for training and testing
X_train = train_df.drop("class", axis=1)
y_train = pd.DataFrame(data=train_df["class"], columns=["class"])
X_test = test_df.drop("class", axis=1)
y_test = pd.DataFrame(data=test_df["class"], columns=["class"])

# Building the model
# Passing trough a lot of different combinaison for the two metaparameters
all_accur = []  # All the accuracies computed of each combinaison of metaparameters
means_accur = []
for i in range(15,40):  # n_estimators
    accur = []
    for j in range(2,5): # max_leaf_nodes = 2**j
        mean_test = []
        for k in range(2):  # numbers trials fo each combinaison of metaparameters
            RFC = RandomForestClassifier(n_estimators=i, max_leaf_nodes=2**j)
            RFC.fit(X_train, y_train)
            RFC_pred = RFC.predict(X_test)
            score = accuracy_score(y_test, RFC_pred)
            mean_test.append(score)
        accur.append(np.mean(mean_test))  # Computation of the mean accuracy for the 20 trials
    all_accur.append(accur)
    means_accur.append(np.mean(accur))

# Searching for the best combinaison of metaparameters
# Function found on internet : https://thispointer.com/python-find-indexes-of-an-element-in-pandas-dataframe/
def getIndexes(dfObj, value):
    ''' Get index positions of value in dataframe i.e. dfObj.'''
    listOfPos = list()
    # Get bool dataframe with True at positions where the given value exists
    result = dfObj.isin([value])
    # Get list of columns that contains the value
    seriesObj = result.any()
    columnNames = list(seriesObj[seriesObj == True].index)
    # Iterate over list of columns and fetch the rows indexes where value exists
    for col in columnNames:
        rows = list(result[col][result[col] == True].index)
        for row in rows:
            listOfPos.append((row, col))
    # Return a list of tuples indicating the positions of value in the dataframe
    return listOfPos

acc = np.array(all_accur) 
t1 = pd.DataFrame(acc, columns =["n_estimators", "1", "2"]) # Creating a dataframe with all the possible combinaisons of metaparameters

max_accur = t1.max().max() # Finding the highest accuracy in the dataframe
indexes = getIndexes(t1, max_accur) # Finding the position of the highest accuracy
index = indexes[0]

N_estimators = index[0]+15  # Best number of estimators 
Max_leaf_nodes = 2**(int(index[1])+2) # Best number of maximum leaf nodes

my_best_forest = RandomForestClassifier(n_estimators=N_estimators, max_leaf_nodes=Max_leaf_nodes)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 3.7508745193481445 seconds ---

# %%
my_best_forest
# Out:
# RandomForestClassifier(max_leaf_nodes=16, n_estimators=21)

# %%
my_best_forest.fit(X_train, y_train)
my_best_forest_pred = my_best_forest.predict(X_test)
accuracy_score(y_test, my_best_forest_pred)
# Out:
# 0.8018867924528302
